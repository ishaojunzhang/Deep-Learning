# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'a', 'term', 'as', 'originated', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.979094
# Nearest to can: waved, conn, logically, almond, generate, coll, tirthankaras, hang,
# Nearest to when: helpful, thoroughbred, orient, nilsson, kou, swiss, crioulo, cherbourg,
# Nearest to its: irate, hitchens, modulating, loma, tomatoes, mantua, confederation, ruin,
# Nearest to at: lighthouses, inward, snowboarding, suzuki, mig, versatile, canonised, augustinians,
# Nearest to while: patronymic, bac, jagan, pup, astounding, raised, dupuis, chairmanship,
# Nearest to between: polydor, orion, tapered, chez, malian, thick, mint, displays,
# Nearest to nine: adele, urbino, locusts, vertebra, differentiates, supremacy, wolves, attribution,
# Nearest to if: trapping, ingmar, sojourn, agilent, virtue, uncover, kazakhstani, embarrassed,
# Nearest to all: abhorrent, stephen, shin, formulas, paedophilia, danielle, locksmithing, delimited,
# Nearest to years: organising, sacr, deum, pave, livia, combinatorics, oshii, heterosexuality,
# Nearest to his: decentralisation, unfortunate, maine, folded, ouster, ayman, thoroughfares, discredit,
# Nearest to to: four, consolidation, charged, hypatia, vacations, broadcasts, mta, basileus,
# Nearest to on: tony, kyiv, impurity, prosthetic, powerfully, proverbs, hides, photographs,
# Nearest to but: otherness, mhz, enigma, skillful, standby, abraham, servants, lemming,
# Nearest to history: solidus, mendelssohn, bodkin, infra, restructuring, hypomanic, points, hein,
# Nearest to s: loud, clanking, heaped, vindication, flensburg, kayaking, gab, calculators,
# Average loss at step 2000: 4.358947
# Average loss at step 4000: 3.863981
# Average loss at step 6000: 3.790865
# Average loss at step 8000: 3.691446
# Average loss at step 10000: 3.612677
# Nearest to can: may, will, would, almond, is, fairbanks, tetris, extreme,
# Nearest to when: lifeboat, nilsson, however, cherbourg, swiss, helpful, famines, after,
# Nearest to its: their, the, ilo, kendall, irate, sutton, elmer, eastbourne,
# Nearest to at: in, capacity, paddy, with, bladed, saguinus, cont, by,
# Nearest to while: although, during, patronymic, conquers, neopaganism, canonic, video, mishandling,
# Nearest to between: orion, in, displays, wry, romero, mint, polydor, enzymatic,
# Nearest to nine: eight, seven, five, six, zero, four, three, two,
# Nearest to if: nino, protection, bakassi, trapping, anjiro, phosphorus, embarrassed, parr,
# Nearest to all: minions, eq, generator, locksmithing, uematsu, different, englishman, strategy,
# Nearest to years: surprisingly, stardust, sacr, hamburgers, premature, livia, books, aleksandar,
# Nearest to his: their, her, the, amerigo, s, turpin, dvo, loving,
# Nearest to to: may, charged, would, broadcasts, will, truths, boat, cho,
# Nearest to on: in, tony, proverbs, by, from, through, octal, at,
# Nearest to but: should, standby, glc, fano, kindly, modulator, dunedin, xing,
# Nearest to history: solidus, release, anchor, installments, alexandrovna, symmetry, rise, bandwidth,
# Nearest to s: his, clanking, montoneros, and, their, loud, ninlil, malaysians,
# Average loss at step 12000: 3.604767
# Average loss at step 14000: 3.569146
# Average loss at step 16000: 3.406742
# Average loss at step 18000: 3.455489
# Average loss at step 20000: 3.541457
# Nearest to can: may, will, would, could, must, might, tetris, should,
# Nearest to when: after, lifeboat, wilmington, although, since, yokoi, because, swiss,
# Nearest to its: their, his, the, excellent, renovation, ilo, some, dating,
# Nearest to at: in, on, opcode, from, and, menial, cretians, schematics,
# Nearest to while: although, during, patronymic, neopaganism, canonic, telegraphic, velocities, when,
# Nearest to between: orion, in, displays, errand, timelines, with, catullus, wry,
# Nearest to nine: eight, six, seven, five, four, three, zero, two,
# Nearest to if: bakassi, embarrassed, should, trapping, is, minimise, kazakhstani, nino,
# Nearest to all: these, many, minions, several, those, recycle, castle, salts,
# Nearest to years: surprisingly, archiepiscopal, stardust, fathered, months, books, times, livia,
# Nearest to his: their, her, its, amerigo, loving, altruist, fosse, the,
# Nearest to to: will, may, would, broadcasts, charged, can, refutable, sle,
# Nearest to on: in, at, tony, through, upon, around, from, proverbs,
# Nearest to but: however, that, argonauts, which, fano, and, should, there,
# Nearest to history: solidus, release, installments, sailor, anchor, symmetry, wikibooks, provability,
# Nearest to s: worry, malaria, clanking, bison, darby, harpers, generalities, arturo,
# Average loss at step 22000: 3.498012
# Average loss at step 24000: 3.489422
# Average loss at step 26000: 3.483017
# Average loss at step 28000: 3.483783
# Average loss at step 30000: 3.506341
# Nearest to can: may, will, would, could, must, might, should, to,
# Nearest to when: after, if, where, however, while, because, though, wilmington,
# Nearest to its: their, his, the, repetitive, elmer, her, eastbourne, sutton,
# Nearest to at: during, in, connector, menial, eek, on, mccormick, opcode,
# Nearest to while: although, during, but, when, canonic, though, telegraphic, totalling,
# Nearest to between: with, in, orion, displays, timelines, catullus, supplier, mongolians,
# Nearest to nine: eight, seven, six, four, five, three, zero, one,
# Nearest to if: when, is, where, could, tarleton, minimise, should, kazakhstani,
# Nearest to all: these, several, many, various, dru, salts, fate, those,
# Nearest to years: months, times, hours, days, archiepiscopal, nino, stardust, year,
# Nearest to his: their, her, its, the, loving, sol, s, lk,
# Nearest to to: can, would, will, refutable, charged, shameful, must, moralistic,
# Nearest to on: upon, through, in, around, under, from, at, proverbs,
# Nearest to but: however, and, while, although, fano, plates, were, resonator,
# Nearest to history: installments, release, solidus, proponent, gohan, hitters, sailor, confronting,
# Nearest to s: clanking, his, samyaksam, nessus, jog, eo, migrating, azerbaijan,
# Average loss at step 32000: 3.499873
# Average loss at step 34000: 3.495344
# Average loss at step 36000: 3.453095
# Average loss at step 38000: 3.295953
# Average loss at step 40000: 3.432141
# Nearest to can: will, may, could, would, must, might, should, cannot,
# Nearest to when: while, if, where, although, during, after, was, however,
# Nearest to its: their, his, the, her, repetitive, universitat, my, pledged,
# Nearest to at: during, on, mccormick, eek, in, connector, cont, storyline,
# Nearest to while: although, when, but, are, though, were, during, and,
# Nearest to between: with, orion, displays, timelines, since, yell, romero, on,
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to if: when, where, is, though, might, flair, shikoku, redneck,
# Nearest to all: these, both, those, various, dru, several, out, sassanians,
# Nearest to years: months, times, days, decades, hours, year, archiepiscopal, occasions,
# Nearest to his: their, her, its, the, s, loving, my, dvo,
# Nearest to to: shameful, will, humoral, hanse, may, truths, broadcasts, can,
# Nearest to on: upon, tony, during, at, around, in, hatchback, within,
# Nearest to but: however, while, although, and, before, fano, generally, require,
# Nearest to history: installments, demographics, release, wikibooks, sled, proponent, solidus, gorbachev,
# Nearest to s: his, clanking, eo, jog, darby, macrocosm, leftist, colorless,
# Average loss at step 42000: 3.432755
# Average loss at step 44000: 3.451742
# Average loss at step 46000: 3.449611
# Average loss at step 48000: 3.352560
# Average loss at step 50000: 3.387669
# Nearest to can: will, may, could, would, must, might, should, cannot,
# Nearest to when: while, if, after, although, however, but, where, before,
# Nearest to its: their, his, the, her, grieg, gruesome, my, orientalis,
# Nearest to at: during, opcode, connector, from, saudis, sle, cronos, mccormick,
# Nearest to while: although, when, but, however, though, after, during, for,
# Nearest to between: with, yell, orion, timelines, among, in, romero, displays,
# Nearest to nine: eight, seven, six, four, three, five, zero, two,
# Nearest to if: when, where, though, could, might, kazakhstani, transcontinental, although,
# Nearest to all: these, both, those, out, any, koufax, various, dru,
# Nearest to years: times, months, days, decades, year, hours, archiepiscopal, occasions,
# Nearest to his: her, their, its, my, the, amerigo, him, ldapv,
# Nearest to to: can, would, may, broadcasts, refutable, will, josie, purports,
# Nearest to on: upon, in, around, through, impurity, octal, from, within,
# Nearest to but: however, although, and, while, when, than, though, obviously,
# Nearest to history: installments, demographics, encyclopedia, release, sled, cystitis, freedom, wikibooks,
# Nearest to s: and, caravan, nagarjuna, clanking, nozzle, whose, flatulence, intercollegiate,
# Average loss at step 52000: 3.439650
# Average loss at step 54000: 3.426799
# Average loss at step 56000: 3.438015
# Average loss at step 58000: 3.402017
# Average loss at step 60000: 3.394505
# Nearest to can: may, will, could, would, must, might, should, cannot,
# Nearest to when: if, because, although, while, after, before, during, though,
# Nearest to its: their, his, the, her, ricardian, several, ilo, selections,
# Nearest to at: during, connector, in, opcode, near, menial, from, magneto,
# Nearest to while: although, though, when, but, before, however, after, during,
# Nearest to between: with, among, in, within, yell, into, through, displays,
# Nearest to nine: eight, six, seven, four, five, three, zero, one,
# Nearest to if: when, where, though, since, before, could, because, honourable,
# Nearest to all: any, those, some, both, many, these, various, each,
# Nearest to years: days, months, times, decades, hours, year, archiepiscopal, occasions,
# Nearest to his: her, their, its, my, the, amerigo, your, loving,
# Nearest to to: will, shameful, humoral, would, replica, refutable, not, broadcasts,
# Nearest to on: upon, through, in, within, calamity, atat, around, impurity,
# Nearest to but: however, and, although, while, though, which, than, see,
# Nearest to history: demographics, consist, sled, list, installments, geography, freedom, bissette,
# Nearest to s: caravan, clanking, harrow, tremors, lachaise, nagarjuna, jog, eo,
# Average loss at step 62000: 3.240751
# Average loss at step 64000: 3.252383
# Average loss at step 66000: 3.403513
# Average loss at step 68000: 3.394222
# Average loss at step 70000: 3.355915
# Nearest to can: may, could, would, will, must, might, should, cannot,
# Nearest to when: if, because, while, however, although, after, before, though,
# Nearest to its: their, the, his, her, amerigo, our, istria, ricardian,
# Nearest to at: during, near, twh, magneto, connector, racine, estranged, opcode,
# Nearest to while: although, though, however, before, when, after, during, including,
# Nearest to between: among, with, within, into, yell, mongolians, bullets, threefold,
# Nearest to nine: eight, seven, six, five, four, zero, three, one,
# Nearest to if: when, though, where, while, for, honourable, before, can,
# Nearest to all: many, some, various, any, every, those, both, several,
# Nearest to years: months, days, decades, times, year, hours, weeks, depressing,
# Nearest to his: her, their, its, my, your, the, loving, our,
# Nearest to to: will, shameful, can, for, would, broadcasts, could, must,
# Nearest to on: upon, through, in, within, around, atat, impurity, from,
# Nearest to but: however, although, which, and, that, while, see, actually,
# Nearest to history: demographics, consist, list, ogg, sled, freedom, geography, career,
# Nearest to s: whose, clanking, the, ustawa, doris, pinkerton, noboa, iigs,
# Average loss at step 72000: 3.373382
# Average loss at step 74000: 3.345437
# Average loss at step 76000: 3.309861
# Average loss at step 78000: 3.348643
# Average loss at step 80000: 3.375971
# Nearest to can: could, will, may, must, would, should, might, cannot,
# Nearest to when: if, before, after, though, while, during, although, because,
# Nearest to its: their, her, his, our, the, your, ricardian, iggy,
# Nearest to at: in, during, mccormick, connector, cont, on, twh, lb,
# Nearest to while: although, though, during, when, however, after, before, but,
# Nearest to between: within, among, with, through, over, timelines, into, yell,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to if: when, though, since, before, can, then, where, because,
# Nearest to all: both, various, every, several, those, any, these, mahendra,
# Nearest to years: days, months, decades, times, year, weeks, hours, seasons,
# Nearest to his: her, their, my, its, your, our, the, loving,
# Nearest to to: shameful, refutable, broadcasts, should, must, replica, sle, would,
# Nearest to on: upon, in, through, around, within, at, cups, during,
# Nearest to but: however, although, while, see, and, though, she, than,
# Nearest to history: ogg, freedom, demographics, installments, consist, sled, edge, cartooning,
# Nearest to s: munroe, darby, clanking, hafnium, intercollegiate, elasticity, fredrik, eb,
# Average loss at step 82000: 3.403788
# Average loss at step 84000: 3.414183
# Average loss at step 86000: 3.392562
# Average loss at step 88000: 3.353955
# Average loss at step 90000: 3.361264
# Nearest to can: could, may, must, will, should, would, might, cannot,
# Nearest to when: if, while, before, after, although, where, because, though,
# Nearest to its: their, his, her, the, our, your, whose, ricardian,
# Nearest to at: during, connector, on, near, in, saguinus, facilitating, before,
# Nearest to while: although, though, when, before, were, during, after, but,
# Nearest to between: among, within, with, into, through, from, under, timelines,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to if: when, though, where, since, is, although, then, before,
# Nearest to all: both, several, every, various, those, many, any, some,
# Nearest to years: months, days, decades, year, hours, times, weeks, centuries,
# Nearest to his: her, their, its, my, your, the, our, amerigo,
# Nearest to to: will, refutable, humoral, would, broadcasts, shameful, moralistic, towards,
# Nearest to on: upon, under, at, through, around, octavio, in, within,
# Nearest to but: however, although, and, while, she, telegraphy, though, who,
# Nearest to history: sled, list, ogg, demographics, uralic, cartooning, consist, geography,
# Nearest to s: whose, blasphemous, clanking, darby, isbn, our, toba, comerica,
# Average loss at step 92000: 3.397046
# Average loss at step 94000: 3.248665
# Average loss at step 96000: 3.358503
# Average loss at step 98000: 3.245034
# Average loss at step 100000: 3.358522
# Nearest to can: could, may, must, will, would, should, cannot, might,
# Nearest to when: if, while, although, before, where, after, though, during,
# Nearest to its: their, his, her, the, our, your, ricardian, iggy,
# Nearest to at: during, on, facilitating, connector, after, once, lb, identifies,
# Nearest to while: although, when, though, but, before, after, during, however,
# Nearest to between: among, within, with, into, through, timelines, yell, inspected,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to if: when, though, since, where, might, flair, defines, before,
# Nearest to all: various, several, both, these, those, many, every, some,
# Nearest to years: months, decades, days, year, weeks, times, hours, centuries,
# Nearest to his: her, their, my, your, its, our, the, lk,
# Nearest to to: could, will, must, acrobat, would, refutable, broadcasts, shameful,
# Nearest to on: upon, through, at, in, within, under, around, facilitating,
# Nearest to but: although, however, and, while, though, when, mammuthus, which,
# Nearest to history: sled, list, ogg, traditional, geography, journal, bourbaki, adequate,
# Nearest to s: whose, clanking, his, munroe, darby, caravan, harmonization, iigs,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch_cbow(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size // num_skips, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[target]
    labels[i, 0] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8 // num_skips)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'a', 'of']
#     labels: ['originated', 'as', 'a', 'term']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['a', 'term', 'anarchism', 'originated', 'of', 'term', 'as', 'originated']
#     labels: ['as', 'a']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size // num_skips, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  segments = [x // num_skips for x in xrange(batch_size)]
  embed_sum = tf.segment_sum(embed, segments)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed_sum,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.104809
# Nearest to no: banishment, bolt, faceted, healing, escorting, aficionados, sebasti, compartments,
# Nearest to he: rory, cinematic, wealthiest, vojt, dialogue, porn, unicef, surrender,
# Nearest to can: baleen, des, diners, purely, meson, watched, orchestra, lya,
# Nearest to first: rnir, postage, occupations, galli, roommate, embryonic, screenings, villainous,
# Nearest to on: compose, cyborg, sinusoidal, dhyana, symmetrically, benefitted, opencyc, erbium,
# Nearest to time: salvo, quarries, struggled, vigilante, moratorium, cliches, endowed, calculation,
# Nearest to of: nernst, lightfoot, psychotherapist, phylum, fundraiser, meta, cheerfully, microorganisms,
# Nearest to united: bergson, knitters, qq, lynda, ramones, rosser, garc, israelite,
# Nearest to when: buber, wolfgang, militarist, chuang, muddy, tk, ukraine, foundational,
# Nearest to but: northampton, abercorn, restraint, memorial, criminalization, exceed, brooks, pharyngeal,
# Nearest to known: reestablish, underdogs, dogs, retrieving, bouncing, forbidden, moravian, quan,
# Nearest to and: newman, transfers, panicked, ulvaeus, tractatus, signifier, reformed, kilmister,
# Nearest to only: ombudsman, glutamate, shroud, uncertain, hindustan, wag, compton, modernism,
# Nearest to two: fayed, abbasid, abound, spend, operas, telescopic, octet, umayyad,
# Nearest to such: sinus, provoke, wolfgang, zel, joys, disgruntled, consultancy, leutze,
# Nearest to up: ruin, gehenna, adriatic, dy, merlin, erecting, rebuffed, mobile,
# Average loss at step 2000: 4.238856
# Average loss at step 4000: 3.648342
# Average loss at step 6000: 3.524928
# Average loss at step 8000: 3.425122
# Average loss at step 10000: 3.300766
# Nearest to no: banishment, magistrate, bolt, painkillers, counterparts, an, vicious, cic,
# Nearest to he: it, who, they, ruth, she, cr, andrey, paperwork,
# Nearest to can: would, will, may, could, must, should, geologically, might,
# Nearest to first: second, last, same, original, third, next, attached, arawak,
# Nearest to on: from, in, hippocratic, feeble, propositional, micronation, microelectronics, into,
# Nearest to time: point, way, year, persecution, promote, vigilante, knew, liberalism,
# Nearest to of: in, overflow, for, carne, intrigues, meta, capitals, plumb,
# Nearest to united: knitters, sleeper, predominately, carver, qq, rosser, israelite, originality,
# Nearest to when: after, indifference, andersen, wolfgang, euphoric, wonderful, by, that,
# Nearest to but: did, nanaimo, while, however, lagged, raps, rosy, will,
# Nearest to known: such, used, defined, well, rahul, nextstep, wizardry, srinagar,
# Nearest to and: or, who, ubiquity, l, shaku, bering, with, huguenot,
# Nearest to only: caution, robbie, rhythmic, env, switching, road, tou, karami,
# Nearest to two: one, five, three, eight, six, four, seven, nine,
# Nearest to such: well, these, known, maidstone, described, amplifiers, provoke, stared,
# Nearest to up: out, ruin, heating, back, acquire, off, camp, wop,
# Average loss at step 12000: 3.227716
# Average loss at step 14000: 3.241573
# Average loss at step 16000: 3.237533
# Average loss at step 18000: 3.267630
# Average loss at step 20000: 3.153295
# Nearest to no: any, banishment, little, magistrate, planckian, diaz, pellet, tractable,
# Nearest to he: she, it, they, who, finally, then, you, anschluss,
# Nearest to can: may, will, would, could, must, should, might, cannot,
# Nearest to first: second, last, same, next, botched, residences, only, jardine,
# Nearest to on: in, through, during, into, viking, upon, using, cyborg,
# Nearest to time: way, knew, emf, promote, year, zealous, faire, wheel,
# Nearest to of: same, intrigues, paternalistic, anxiolytics, fairey, micas, oi, cory,
# Nearest to united: metis, knitters, predominately, cortez, albatrosses, sargent, sleeper, boehm,
# Nearest to when: if, before, after, while, during, where, though, aggadic,
# Nearest to but: however, esk, julien, see, known, marksmanship, entertaining, clear,
# Nearest to known: used, such, described, defined, well, far, called, regarded,
# Nearest to and: or, bevan, omniglot, shockley, soaked, earnestly, lexus, from,
# Nearest to only: even, also, always, still, sharing, robbie, superb, not,
# Nearest to two: three, one, five, eight, six, four, nine, seven,
# Nearest to such: known, well, these, described, many, regarded, chicken, trades,
# Nearest to up: off, out, back, them, him, down, ruin, postulate,
# Average loss at step 22000: 3.203788
# Average loss at step 24000: 2.993428
# Average loss at step 26000: 2.865395
# Average loss at step 28000: 3.108508
# Average loss at step 30000: 3.055972
# Nearest to no: little, an, magistrate, vicious, theologians, dst, doris, yang,
# Nearest to he: she, it, they, who, there, remark, ramone, sweetened,
# Nearest to can: may, will, could, would, must, should, might, cannot,
# Nearest to first: second, last, same, next, best, third, original, disintegrated,
# Nearest to on: upon, through, about, in, micronation, around, into, under,
# Nearest to time: year, knew, way, emf, novum, twelfth, case, month,
# Nearest to of: nuisance, in, for, maronite, intrigues, throughout, including, shatila,
# Nearest to united: knitters, cortez, metis, predominately, exocet, lupus, canc, albatrosses,
# Nearest to when: before, if, where, ichi, while, after, though, however,
# Nearest to but: although, however, while, did, and, would, though, found,
# Nearest to known: used, defined, such, described, regarded, well, seen, considered,
# Nearest to and: or, including, but, while, than, bmc, vitrification, whitish,
# Nearest to only: robbie, do, manama, aam, last, ever, cuttlefish, run,
# Nearest to two: five, three, seven, four, six, one, zero, nine,
# Nearest to such: these, known, well, regarded, some, magistrates, serve, maidstone,
# Nearest to up: off, them, down, out, back, him, usc, postulate,
# Average loss at step 32000: 3.037768
# Average loss at step 34000: 3.055753
# Average loss at step 36000: 3.020586
# Average loss at step 38000: 2.963513
# Average loss at step 40000: 2.968011
# Nearest to no: little, painkillers, nothing, menlo, closely, stadia, fannish, breathe,
# Nearest to he: she, it, they, there, who, we, this, finally,
# Nearest to can: will, may, could, must, would, cannot, might, should,
# Nearest to first: second, last, third, final, next, same, original, entering,
# Nearest to on: upon, in, through, within, cyborg, straddle, under, at,
# Nearest to time: year, knew, timer, strat, capacity, zealous, debate, debates,
# Nearest to of: including, from, rstenberg, umi, qoheleth, concerning, throughout, lakers,
# Nearest to united: losers, guardia, ghazi, city, metis, vc, valentin, knitters,
# Nearest to when: before, if, where, after, although, though, while, however,
# Nearest to but: however, although, deduces, while, hijack, than, though, when,
# Nearest to known: regarded, defined, used, described, such, called, considered, viewed,
# Nearest to and: or, while, omniglot, including, deoxygenated, ribosome, cts, eyepiece,
# Nearest to only: last, since, run, robbie, plebs, next, navajo, first,
# Nearest to two: three, four, eight, six, one, seven, five, nine,
# Nearest to such: well, known, regarded, quan, opposed, various, defined, yarns,
# Nearest to up: off, down, out, back, them, him, usc, rendition,
# Average loss at step 42000: 2.989905
# Average loss at step 44000: 3.024596
# Average loss at step 46000: 3.032187
# Average loss at step 48000: 2.987307
# Average loss at step 50000: 2.938539
# Nearest to no: any, little, only, menlo, painkillers, fruition, magistrate, verdict,
# Nearest to he: she, it, they, there, we, enlil, who, circa,
# Nearest to can: may, must, should, could, would, might, cannot, will,
# Nearest to first: last, second, third, same, next, eighth, best, final,
# Nearest to on: upon, in, around, schechter, about, waza, willi, micronation,
# Nearest to time: papen, year, herr, knew, zealous, timer, amuse, antecedents,
# Nearest to of: for, including, chilled, enters, qoheleth, smoother, at, lading,
# Nearest to united: european, vc, losers, guardia, southern, uk, ghazi, valentin,
# Nearest to when: if, before, though, until, after, while, since, during,
# Nearest to but: however, or, it, cabinda, appear, lakers, sartre, hokkaido,
# Nearest to known: used, described, such, defined, referred, considered, regarded, possible,
# Nearest to and: or, s, hamitic, while, divina, relator, including, where,
# Nearest to only: still, always, no, do, joyous, mistranslation, generally, thoughts,
# Nearest to two: three, five, four, seven, one, eight, zero, six,
# Nearest to such: well, known, regarded, these, identified, opposed, described, serve,
# Nearest to up: off, out, back, them, down, rendition, usc, ugarit,
# Average loss at step 52000: 2.937243
# Average loss at step 54000: 2.970846
# Average loss at step 56000: 2.820528
# Average loss at step 58000: 2.917933
# Average loss at step 60000: 2.818356
# Nearest to no: any, only, nothing, vicious, little, attachment, painkillers, even,
# Nearest to he: she, it, they, who, finally, formally, never, there,
# Nearest to can: may, could, should, must, will, would, might, cannot,
# Nearest to first: second, last, next, third, best, same, final, entire,
# Nearest to on: upon, within, around, onto, against, turpin, until, during,
# Nearest to time: year, range, distance, zealous, way, capacity, timer, term,
# Nearest to of: during, chilled, micas, umi, concerning, ediacaran, ultima, nuisance,
# Nearest to united: boehm, guardia, albatrosses, southern, vc, losers, following, soviet,
# Nearest to when: while, before, until, after, where, though, if, although,
# Nearest to but: although, did, however, do, since, while, will, where,
# Nearest to known: used, such, described, regarded, defined, available, possible, seen,
# Nearest to and: or, while, including, silicone, bmc, weathering, although, peanuts,
# Nearest to only: always, even, never, no, not, struma, hulled, compensated,
# Nearest to two: three, six, four, eight, seven, five, nine, zero,
# Nearest to such: known, well, these, follows, regarded, defined, serve, including,
# Nearest to up: out, off, back, him, them, down, usc, together,
# Average loss at step 62000: 2.910786
# Average loss at step 64000: 2.902197
# Average loss at step 66000: 2.878347
# Average loss at step 68000: 2.857150
# Average loss at step 70000: 2.904359
# Nearest to no: some, little, another, any, theologians, menlo, a, undergoing,
# Nearest to he: she, it, they, who, finally, never, we, subsequently,
# Nearest to can: could, may, must, would, should, cannot, might, will,
# Nearest to first: second, next, last, original, previous, bathe, entire, third,
# Nearest to on: upon, in, onto, micronation, within, neologism, through, waza,
# Nearest to time: strat, overload, zealous, power, way, cheered, benny, knew,
# Nearest to of: whose, including, formative, include, elmendorf, intrigues, for, in,
# Nearest to united: following, guardia, boehm, beginning, ellery, deprecated, losers, rhee,
# Nearest to when: where, after, while, before, although, if, for, until,
# Nearest to but: however, and, while, than, although, it, see, abb,
# Nearest to known: used, defined, described, such, called, possible, referred, regarded,
# Nearest to and: or, including, etc, but, liturgics, which, stanislaus, staffing,
# Nearest to only: always, do, until, easily, even, actually, never, octaves,
# Nearest to two: three, six, four, five, eight, seven, one, nine,
# Nearest to such: known, these, well, defined, many, several, certain, blume,
# Nearest to up: out, off, back, down, him, them, popped, usc,
# Average loss at step 72000: 2.821068
# Average loss at step 74000: 2.655349
# Average loss at step 76000: 2.847109
# Average loss at step 78000: 2.811299
# Average loss at step 80000: 2.845441
# Nearest to no: menlo, any, vicious, another, shaping, become, unwittingly, hydroxyl,
# Nearest to he: she, it, they, we, never, subsequently, finally, quickly,
# Nearest to can: may, will, could, should, must, might, cannot, would,
# Nearest to first: second, last, next, original, same, bathe, third, fourth,
# Nearest to on: upon, through, within, onto, around, in, inside, micronation,
# Nearest to time: zealous, timer, jhana, pejoratively, overload, benny, month, laszlo,
# Nearest to of: in, township, although, and, humanistic, rstenberg, concerning, intrigues,
# Nearest to united: european, guardia, border, southwestern, boehm, following, rhee, usa,
# Nearest to when: before, if, after, where, unless, although, while, until,
# Nearest to but: however, though, although, tesco, and, who, see, she,
# Nearest to known: described, seen, defined, such, used, regarded, possible, called,
# Nearest to and: UNK, although, but, in, liturgics, including, moderators, where,
# Nearest to only: always, kocher, meantime, until, adequately, bulldogs, last, just,
# Nearest to two: three, four, six, eight, seven, five, one, zero,
# Nearest to such: known, these, ruskin, regarded, well, blume, serve, follows,
# Nearest to up: off, out, down, back, him, them, together, reification,
# Average loss at step 82000: 2.832173
# Average loss at step 84000: 2.821609
# Average loss at step 86000: 2.796219
# Average loss at step 88000: 2.648494
# Average loss at step 90000: 2.760083
# Nearest to no: any, nothing, another, little, metroid, pretenders, annunzio, menlo,
# Nearest to he: she, they, it, there, we, originally, who, eventually,
# Nearest to can: could, must, should, might, may, will, cannot, would,
# Nearest to first: last, second, next, biggest, original, fourth, third, previous,
# Nearest to on: upon, within, in, under, through, towards, into, ansi,
# Nearest to time: distance, overload, month, zealous, power, life, distances, timer,
# Nearest to of: in, sponge, including, interwoven, rstenberg, intrigues, for, after,
# Nearest to united: guardia, losers, boehm, following, president, southwestern, uk, masterpieces,
# Nearest to when: if, before, though, unless, where, after, thus, until,
# Nearest to but: however, than, generally, though, unreasonable, and, see, aldiss,
# Nearest to known: possible, defined, described, recognized, referred, such, regarded, used,
# Nearest to and: or, including, while, see, but, kinematic, concerning, however,
# Nearest to only: always, nanometer, kocher, still, any, elegantly, just, last,
# Nearest to two: three, four, six, eight, seven, five, zero, nine,
# Nearest to such: known, these, blume, follows, stylistic, well, identified, ruskin,
# Nearest to up: off, back, down, out, together, beginning, them, him,
# Average loss at step 92000: 2.716198
# Average loss at step 94000: 2.729562
# Average loss at step 96000: 2.765677
# Average loss at step 98000: 2.727955
# Average loss at step 100000: 2.774842
# Nearest to no: nothing, ssbauer, analogously, undergoing, iala, withheld, nasrallah, charged,
# Nearest to he: she, it, they, who, we, there, originally, eventually,
# Nearest to can: must, should, may, cannot, might, will, would, could,
# Nearest to first: last, next, second, fourth, latter, best, remaining, vrije,
# Nearest to on: upon, within, in, under, towards, through, regarding, concerning,
# Nearest to time: timer, year, degree, distances, intervenes, tca, period, iss,
# Nearest to of: intrigues, nuisance, concerning, throughout, by, for, interwoven, umi,
# Nearest to united: guardia, british, losers, federated, boehm, valentin, southwestern, rhee,
# Nearest to when: after, before, if, unless, while, although, during, where,
# Nearest to but: however, and, rated, though, vehement, there, aldiss, endosymbiosis,
# Nearest to known: described, regarded, such, defined, used, recognized, possible, referred,
# Nearest to and: or, including, callithrix, although, but, whose, relator, especially,
# Nearest to only: typically, always, simply, actually, really, best, generally, probably,
# Nearest to two: three, five, four, seven, six, one, eight, zero,
# Nearest to such: known, well, follows, blume, few, opposed, stylistic, defined,
# Nearest to up: off, down, back, them, forward, out, together, popped,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
