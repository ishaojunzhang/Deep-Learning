# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.655839
# Minibatch accuracy: 12.5%
# Validation accuracy: 11.0%
# Minibatch loss at step 50: 1.547545
# Minibatch accuracy: 43.8%
# Validation accuracy: 44.5%
# Minibatch loss at step 100: 1.067843
# Minibatch accuracy: 75.0%
# Validation accuracy: 68.1%
# Minibatch loss at step 150: 0.518194
# Minibatch accuracy: 81.2%
# Validation accuracy: 74.7%
# Minibatch loss at step 200: 0.761474
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.8%
# Minibatch loss at step 250: 1.191616
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.5%
# Minibatch loss at step 300: 0.382617
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.4%
# Minibatch loss at step 350: 0.530289
# Minibatch accuracy: 87.5%
# Validation accuracy: 76.8%
# Minibatch loss at step 400: 0.294045
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.0%
# Minibatch loss at step 450: 0.711202
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.9%
# Minibatch loss at step 500: 0.841081
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.1%
# Minibatch loss at step 550: 0.830290
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.5%
# Minibatch loss at step 600: 0.333108
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.3%
# Minibatch loss at step 650: 0.809518
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.2%
# Minibatch loss at step 700: 0.981472
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.7%
# Minibatch loss at step 750: 0.058048
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.4%
# Minibatch loss at step 800: 0.695481
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.5%
# Minibatch loss at step 850: 1.013898
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 900: 0.519706
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.5%
# Minibatch loss at step 950: 0.772377
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 1000: 0.462302
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.8%
# Test accuracy: 88.5%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv1 = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    bias1 = tf.nn.relu(conv1 + layer1_biases)
    pool1 = tf.nn.max_pool(bias1, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    conv2 = tf.nn.conv2d(pool1, layer2_weights, [1, 1, 1, 1], padding='SAME')
    bias2 = tf.nn.relu(conv2 + layer2_biases)
    pool2 = tf.nn.max_pool(bias2, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    shape = pool2.get_shape().as_list()
    reshape = tf.reshape(pool2, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 4.063267
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.700625
# Minibatch accuracy: 43.8%
# Validation accuracy: 39.2%
# Minibatch loss at step 100: 1.094621
# Minibatch accuracy: 50.0%
# Validation accuracy: 62.0%
# Minibatch loss at step 150: 0.554021
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.1%
# Minibatch loss at step 200: 1.091213
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.9%
# Minibatch loss at step 250: 0.933342
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.0%
# Minibatch loss at step 300: 0.417585
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.5%
# Minibatch loss at step 350: 0.511372
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.9%
# Minibatch loss at step 400: 0.247524
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.8%
# Minibatch loss at step 450: 0.787746
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.3%
# Minibatch loss at step 500: 0.583124
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.0%
# Minibatch loss at step 550: 0.747644
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.1%
# Minibatch loss at step 600: 0.386603
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 650: 0.918126
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.1%
# Minibatch loss at step 700: 0.747113
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.4%
# Minibatch loss at step 750: 0.068878
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.9%
# Minibatch loss at step 800: 0.621744
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.8%
# Minibatch loss at step 850: 0.962716
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.5%
# Minibatch loss at step 900: 0.595242
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.8%
# Minibatch loss at step 950: 0.579910
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.2%
# Minibatch loss at step 1000: 0.352894
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.2%
# Test accuracy: 90.7%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth1 = 6
depth2 = 16
num_hidden1 = 120
num_hidden2 = 84

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth1], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth1]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth1, depth2], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth2]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth2, num_hidden1], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden1]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden1, num_hidden2], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden2]))
  layer5_weights = tf.Variable(tf.truncated_normal(
      [num_hidden2, num_labels], stddev=0.1))
  layer5_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data, keep_prob):
    conv1 = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    bias1 = tf.nn.relu(conv1 + layer1_biases)
    pool1 = tf.nn.max_pool(bias1, [1, 2, 2, 1], [1, 2, 2, 1], padding='VALID')
    conv2 = tf.nn.conv2d(pool1, layer2_weights, [1, 1, 1, 1], padding='VALID')
    bias2 = tf.nn.relu(conv2 + layer2_biases)
    pool2 = tf.nn.max_pool(bias2, [1, 2, 2, 1], [1, 2, 2, 1], padding='VALID')
    conv3 = tf.nn.conv2d(pool2, layer3_weights, [1, 1, 1, 1], padding='VALID')
    bias3 = tf.nn.relu(conv3 + layer3_biases)
    shape = bias3.get_shape().as_list()
    reshape = tf.reshape(bias3, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer4_weights) + layer4_biases)
    drop = tf.nn.dropout(hidden, keep_prob)
    return tf.matmul(drop, layer5_weights) + layer5_biases
  
  # Training computation.
  logits = model(tf_train_dataset, 0.5)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(0.05, global_step, 100000, 0.96)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
    
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset, 1.0))
  test_prediction = tf.nn.softmax(model(tf_test_dataset, 1.0))

# %%
num_steps = 10001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 5.613974
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.301162
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 100: 2.301699
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 150: 2.286890
# Minibatch accuracy: 25.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 200: 2.307390
# Minibatch accuracy: 12.5%
# Validation accuracy: 22.8%
# Minibatch loss at step 250: 2.428644
# Minibatch accuracy: 0.0%
# Validation accuracy: 24.0%
# Minibatch loss at step 300: 1.899622
# Minibatch accuracy: 31.2%
# Validation accuracy: 51.9%
# Minibatch loss at step 350: 1.120211
# Minibatch accuracy: 62.5%
# Validation accuracy: 61.7%
# Minibatch loss at step 400: 0.947732
# Minibatch accuracy: 68.8%
# Validation accuracy: 68.8%
# Minibatch loss at step 450: 0.755873
# Minibatch accuracy: 81.2%
# Validation accuracy: 71.7%
# Minibatch loss at step 500: 1.291739
# Minibatch accuracy: 62.5%
# Validation accuracy: 74.4%
# Minibatch loss at step 550: 0.754757
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.2%
# Minibatch loss at step 600: 0.542560
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.0%
# Minibatch loss at step 650: 0.947922
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.9%
# Minibatch loss at step 700: 1.093920
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.9%
# Minibatch loss at step 750: 0.153200
# Minibatch accuracy: 100.0%
# Validation accuracy: 80.0%
# Minibatch loss at step 800: 0.780417
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.5%
# Minibatch loss at step 850: 0.786907
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.8%
# Minibatch loss at step 900: 0.681312
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.0%
# Minibatch loss at step 950: 0.994259
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.9%
# Minibatch loss at step 1000: 0.569079
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.5%
# Minibatch loss at step 1050: 0.658577
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.9%
# Minibatch loss at step 1100: 0.830090
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.8%
# Minibatch loss at step 1150: 0.511215
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.2%
# Minibatch loss at step 1200: 0.854601
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.5%
# Minibatch loss at step 1250: 0.657776
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.4%
# Minibatch loss at step 1300: 0.344711
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.4%
# Minibatch loss at step 1350: 0.939646
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.2%
# Minibatch loss at step 1400: 0.314512
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.6%
# Minibatch loss at step 1450: 0.408381
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.0%
# Minibatch loss at step 1500: 0.955115
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.1%
# Minibatch loss at step 1550: 0.662000
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 1600: 1.166348
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.9%
# Minibatch loss at step 1650: 0.688995
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.5%
# Minibatch loss at step 1700: 0.561313
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.6%
# Minibatch loss at step 1750: 0.627366
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.6%
# Minibatch loss at step 1800: 0.537941
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.9%
# Minibatch loss at step 1850: 1.020734
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.8%
# Minibatch loss at step 1900: 0.362839
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.9%
# Minibatch loss at step 1950: 0.651752
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.2%
# Minibatch loss at step 2000: 0.274166
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.4%
# Minibatch loss at step 2050: 1.024561
# Minibatch accuracy: 62.5%
# Validation accuracy: 83.6%
# Minibatch loss at step 2100: 0.324396
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.8%
# Minibatch loss at step 2150: 0.566659
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.4%
# Minibatch loss at step 2200: 0.319379
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.5%
# Minibatch loss at step 2250: 0.393352
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.7%
# Minibatch loss at step 2300: 1.295213
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.2%
# Minibatch loss at step 2350: 0.602324
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.3%
# Minibatch loss at step 2400: 0.735656
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.7%
# Minibatch loss at step 2450: 0.380203
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.7%
# Minibatch loss at step 2500: 0.838744
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.8%
# Minibatch loss at step 2550: 0.649621
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.0%
# Minibatch loss at step 2600: 0.361826
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.8%
# Minibatch loss at step 2650: 0.384656
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.1%
# Minibatch loss at step 2700: 0.479939
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.1%
# Minibatch loss at step 2750: 1.146084
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.1%
# Minibatch loss at step 2800: 0.640870
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.5%
# Minibatch loss at step 2850: 0.121975
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 2900: 0.578114
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.6%
# Minibatch loss at step 2950: 0.333732
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 3000: 0.882058
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.0%
# Minibatch loss at step 3050: 0.266962
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.9%
# Minibatch loss at step 3100: 0.331939
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.2%
# Minibatch loss at step 3150: 0.898485
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.5%
# Minibatch loss at step 3200: 0.425948
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 3250: 0.480183
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.4%
# Minibatch loss at step 3300: 0.099225
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 3350: 0.249416
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 3400: 0.538926
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.1%
# Minibatch loss at step 3450: 0.474304
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 3500: 0.269968
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.0%
# Minibatch loss at step 3550: 0.336286
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 3600: 0.061074
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.0%
# Minibatch loss at step 3650: 0.931050
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.4%
# Minibatch loss at step 3700: 0.912388
# Minibatch accuracy: 62.5%
# Validation accuracy: 86.0%
# Minibatch loss at step 3750: 0.959559
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 3800: 0.021411
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.0%
# Minibatch loss at step 3850: 0.766138
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.3%
# Minibatch loss at step 3900: 0.621066
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.0%
# Minibatch loss at step 3950: 0.017546
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.8%
# Minibatch loss at step 4000: 0.658238
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.2%
# Minibatch loss at step 4050: 0.818662
# Minibatch accuracy: 68.8%
# Validation accuracy: 85.9%
# Minibatch loss at step 4100: 0.485603
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.1%
# Minibatch loss at step 4150: 0.763505
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.0%
# Minibatch loss at step 4200: 0.185869
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# Minibatch loss at step 4250: 0.720873
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.8%
# Minibatch loss at step 4300: 0.590666
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.3%
# Minibatch loss at step 4350: 0.359421
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.4%
# Minibatch loss at step 4400: 1.172499
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.5%
# Minibatch loss at step 4450: 0.430271
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 4500: 0.639068
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.8%
# Minibatch loss at step 4550: 0.210457
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.0%
# Minibatch loss at step 4600: 0.559378
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 4650: 1.439941
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.4%
# Minibatch loss at step 4700: 0.401387
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# Minibatch loss at step 4750: 1.207225
# Minibatch accuracy: 56.2%
# Validation accuracy: 85.9%
# Minibatch loss at step 4800: 0.467003
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.3%
# Minibatch loss at step 4850: 0.335341
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss at step 4900: 0.262470
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.5%
# Minibatch loss at step